# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense, Input
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Load Dataset
df = pd.read_csv("Lab exp1.csv", sep=';')

# %%
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.dtypes
# Out:
# school          str
# sex             str
# age           int64
# address         str
# famsize         str
# Pstatus         str
# Medu          int64
# Fedu          int64
# Mjob            str
# Fjob            str
# reason          str
# guardian        str
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# romantic        str
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
# Encode categorical columns

for col in df.columns:

    # Encode any non-numeric column
    if df[col].dtype == 'object' or df[col].dtype == 'str':

        le = LabelEncoder()

        df[col] = le.fit_transform(
            df[col].astype(str)
        )

# Verify conversion
print(df.dtypes)
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# Mjob          int64
# Fjob          int64
# reason        int64
# guardian      int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
# Features and Target

X = df.drop("G3", axis=1)
Y = df["G3"]

# Convert to numpy
X = X.to_numpy(dtype=np.float32)
Y = Y.to_numpy(dtype=np.float32)

# %%
# Normalize features

scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
# Train-Test Split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# %%
# Build Neural Network

model = Sequential([
    Input(shape=(X_train.shape[1],)),

    Dense(128, activation='relu'),

    Dense(64, activation='relu'),

    Dense(32, activation='relu'),

    # Output layer for grade prediction
    Dense(1)
])

# %%
# Compile Model

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,593 (57.00 KB)
#  Trainable params: 14,593 (57.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model

history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 106.9390 - mae: 9.4270 - val_loss: 91.3543 - val_mae: 8.8956
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 78.4940 - mae: 8.0792 - val_loss: 60.4893 - val_mae: 7.1571
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 47.1134 - mae: 6.0888 - val_loss: 29.1596 - val_mae: 4.6791
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24.1668 - mae: 3.9847 - val_loss: 16.0613 - val_mae: 2.9948
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.5572 - mae: 3.2153 - val_loss: 14.2549 - val_mae: 2.6477
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 13.7222 - mae: 2.6902 - val_loss: 10.6275 - val_mae: 2.3254
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.7974 - mae: 2.3705 - val_loss: 9.5805 - val_mae: 2.3127
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.0783 - mae: 2.1656 - val_loss: 8.6406 - val_mae: 2.0670
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8348 - mae: 1.9000 - val_loss: 8.3234 - val_mae: 1.9907
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.1242 - mae: 1.7954 - val_loss: 7.8702 - val_mae: 1.9775
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4566 - mae: 1.7223 - val_loss: 7.4722 - val_mae: 1.9725
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0337 - mae: 1.6710 - val_loss: 7.2294 - val_mae: 1.9640
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6204 - mae: 1.5954 - val_loss: 7.1284 - val_mae: 1.9600
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2786 - mae: 1.5376 - val_loss: 6.9604 - val_mae: 1.9745
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9576 - mae: 1.4883 - val_loss: 6.8979 - val_mae: 1.9816
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6772 - mae: 1.4411 - val_loss: 6.7401 - val_mae: 1.9852
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4000 - mae: 1.3872 - val_loss: 6.7300 - val_mae: 1.9880
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2074 - mae: 1.3359 - val_loss: 6.6781 - val_mae: 1.9846
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9664 - mae: 1.3014 - val_loss: 6.5070 - val_mae: 1.9892
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7445 - mae: 1.2480 - val_loss: 6.5979 - val_mae: 1.9777
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5485 - mae: 1.1924 - val_loss: 6.4536 - val_mae: 1.9664
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3431 - mae: 1.1435 - val_loss: 6.3240 - val_mae: 1.9549
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1673 - mae: 1.1008 - val_loss: 6.2528 - val_mae: 1.9525
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0251 - mae: 1.0630 - val_loss: 6.2818 - val_mae: 1.9545
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8687 - mae: 1.0202 - val_loss: 6.1204 - val_mae: 1.9400
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7091 - mae: 0.9687 - val_loss: 6.1742 - val_mae: 1.9338
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5692 - mae: 0.9236 - val_loss: 6.0084 - val_mae: 1.9170
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4329 - mae: 0.8772 - val_loss: 5.8870 - val_mae: 1.9234
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3119 - mae: 0.8423 - val_loss: 5.8504 - val_mae: 1.8961
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1974 - mae: 0.7953 - val_loss: 5.8681 - val_mae: 1.8921
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0972 - mae: 0.7618 - val_loss: 5.8747 - val_mae: 1.8965
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0076 - mae: 0.7289 - val_loss: 5.8061 - val_mae: 1.8841
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9265 - mae: 0.6957 - val_loss: 5.7299 - val_mae: 1.8653
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8473 - mae: 0.6681 - val_loss: 5.6181 - val_mae: 1.8683
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7671 - mae: 0.6307 - val_loss: 5.7818 - val_mae: 1.8542
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7063 - mae: 0.6061 - val_loss: 5.6046 - val_mae: 1.8456
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6346 - mae: 0.5653 - val_loss: 5.6005 - val_mae: 1.8250
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5845 - mae: 0.5424 - val_loss: 5.5845 - val_mae: 1.8289
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5346 - mae: 0.5235 - val_loss: 5.5814 - val_mae: 1.8101
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4943 - mae: 0.4989 - val_loss: 5.4305 - val_mae: 1.8026
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4651 - mae: 0.4968 - val_loss: 5.4966 - val_mae: 1.8029
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4306 - mae: 0.4658 - val_loss: 5.5687 - val_mae: 1.7954
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3839 - mae: 0.4385 - val_loss: 5.3746 - val_mae: 1.7881
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3443 - mae: 0.4184 - val_loss: 5.4646 - val_mae: 1.7692
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3091 - mae: 0.3920 - val_loss: 5.2988 - val_mae: 1.7662
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2819 - mae: 0.3723 - val_loss: 5.4033 - val_mae: 1.7553
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2618 - mae: 0.3650 - val_loss: 5.3427 - val_mae: 1.7591
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2383 - mae: 0.3432 - val_loss: 5.3854 - val_mae: 1.7540
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2181 - mae: 0.3290 - val_loss: 5.3397 - val_mae: 1.7442
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1996 - mae: 0.3134 - val_loss: 5.3380 - val_mae: 1.7409
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1817 - mae: 0.2965 - val_loss: 5.2692 - val_mae: 1.7309
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1667 - mae: 0.2851 - val_loss: 5.3337 - val_mae: 1.7298
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1536 - mae: 0.2745 - val_loss: 5.3228 - val_mae: 1.7257
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1382 - mae: 0.2582 - val_loss: 5.2514 - val_mae: 1.7187
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1249 - mae: 0.2463 - val_loss: 5.2963 - val_mae: 1.7210
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1141 - mae: 0.2352 - val_loss: 5.2912 - val_mae: 1.7251
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1047 - mae: 0.2251 - val_loss: 5.3145 - val_mae: 1.7237
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0934 - mae: 0.2134 - val_loss: 5.2667 - val_mae: 1.7181
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0838 - mae: 0.1978 - val_loss: 5.2732 - val_mae: 1.7180
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0774 - mae: 0.1921 - val_loss: 5.2797 - val_mae: 1.7143
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0701 - mae: 0.1842 - val_loss: 5.3183 - val_mae: 1.7207
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0629 - mae: 0.1749 - val_loss: 5.2664 - val_mae: 1.7122
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0571 - mae: 0.1633 - val_loss: 5.2789 - val_mae: 1.7159
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0524 - mae: 0.1558 - val_loss: 5.2970 - val_mae: 1.7186
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0470 - mae: 0.1478 - val_loss: 5.2964 - val_mae: 1.7137
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0426 - mae: 0.1405 - val_loss: 5.2729 - val_mae: 1.7127
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0391 - mae: 0.1353 - val_loss: 5.2797 - val_mae: 1.7141
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0361 - mae: 0.1291 - val_loss: 5.3120 - val_mae: 1.7132
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0327 - mae: 0.1225 - val_loss: 5.2709 - val_mae: 1.7127
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0295 - mae: 0.1173 - val_loss: 5.2793 - val_mae: 1.7138
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0261 - mae: 0.1099 - val_loss: 5.2921 - val_mae: 1.7077
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0238 - mae: 0.1045 - val_loss: 5.2656 - val_mae: 1.7079
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0217 - mae: 0.0980 - val_loss: 5.3055 - val_mae: 1.7088
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0202 - mae: 0.0972 - val_loss: 5.2518 - val_mae: 1.7081
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0178 - mae: 0.0904 - val_loss: 5.2857 - val_mae: 1.7034
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0156 - mae: 0.0841 - val_loss: 5.2621 - val_mae: 1.7056
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0148 - mae: 0.0817 - val_loss: 5.2993 - val_mae: 1.7039
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0134 - mae: 0.0780 - val_loss: 5.2314 - val_mae: 1.7032
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0123 - mae: 0.0743 - val_loss: 5.2841 - val_mae: 1.7015
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0106 - mae: 0.0668 - val_loss: 5.2351 - val_mae: 1.6972
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0097 - mae: 0.0644 - val_loss: 5.2479 - val_mae: 1.6993
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0088 - mae: 0.0599 - val_loss: 5.2701 - val_mae: 1.6991
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0082 - mae: 0.0593 - val_loss: 5.2487 - val_mae: 1.6976
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0073 - mae: 0.0551 - val_loss: 5.2577 - val_mae: 1.6968
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064 - mae: 0.0500 - val_loss: 5.2524 - val_mae: 1.6956
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - mae: 0.0497 - val_loss: 5.2542 - val_mae: 1.6964
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - mae: 0.0456 - val_loss: 5.2442 - val_mae: 1.6938
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - mae: 0.0430 - val_loss: 5.2425 - val_mae: 1.6932
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - mae: 0.0405 - val_loss: 5.2464 - val_mae: 1.6918
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - mae: 0.0392 - val_loss: 5.2395 - val_mae: 1.6929
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035 - mae: 0.0377 - val_loss: 5.2592 - val_mae: 1.6933
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - mae: 0.0352 - val_loss: 5.2295 - val_mae: 1.6903
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - mae: 0.0327 - val_loss: 5.2520 - val_mae: 1.6922
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0321 - val_loss: 5.2525 - val_mae: 1.6907
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025 - mae: 0.0307 - val_loss: 5.2321 - val_mae: 1.6893
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - mae: 0.0303 - val_loss: 5.2439 - val_mae: 1.6895
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - mae: 0.0273 - val_loss: 5.2420 - val_mae: 1.6892
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0019 - mae: 0.0264 - val_loss: 5.2387 - val_mae: 1.6893
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - mae: 0.0246 - val_loss: 5.2493 - val_mae: 1.6887
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - mae: 0.0234 - val_loss: 5.2452 - val_mae: 1.6884

# %%
# Evaluate

test_loss, test_mae = model.evaluate(
    X_test,
    Y_test
)

print(f"\nTest MAE: {test_mae:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.4710 - mae: 2.0998
#
# Test MAE: 2.0998

# %%
# Predict first 5 students

predictions = model.predict(X_test[:5])

for i in range(5):

    predicted_grade = predictions[i][0]

    print(f"\nStudent {i+1}")

    print(f"Actual Grade: {Y_test[i]}")

    print(
        f"Predicted Grade: "
        f"{predicted_grade:.2f}"
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# Student 1
# Actual Grade: 10.0
# Predicted Grade: 6.90
#
# Student 2
# Actual Grade: 12.0
# Predicted Grade: 9.48
#
# Student 3
# Actual Grade: 5.0
# Predicted Grade: 3.44
#
# Student 4
# Actual Grade: 10.0
# Predicted Grade: 8.71
#
# Student 5
# Actual Grade: 9.0
# Predicted Grade: 12.17
