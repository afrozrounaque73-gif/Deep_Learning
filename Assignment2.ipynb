# %%
# !pip install kagglehub tensorflow
# Out:
# Requirement already satisfied: kagglehub in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (0.3.13)
# Requirement already satisfied: tensorflow in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (2.20.0)
# Requirement already satisfied: packaging in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from kagglehub) (4.68.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (6.33.6)
# Requirement already satisfied: setuptools in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (3.21.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Requirement already satisfied: colorama in c:\users\maharshi goswami\anaconda3\envs\project\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import os

# %%
path = kagglehub.dataset_download(
    "asdasdasasdas/garbage-classification"
)

print("Dataset Downloaded At:")
print(path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.2).
# Dataset Downloaded At:
# C:\Users\Maharshi Goswami\.cache\kagglehub\datasets\asdasdasasdas\garbage-classification\versions\2

# %%
# Dataset Path
dataset_path = os.path.join(path, "Garbage classification")

print("Dataset Folder:", dataset_path)
# Out:
# Dataset Folder: C:\Users\Maharshi Goswami\.cache\kagglehub\datasets\asdasdasasdas\garbage-classification\versions\2\Garbage classification

# %%
train = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(128,128),
    batch_size=32
)

val = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(128,128),
    batch_size=32
)
# Out:
# Found 2527 files belonging to 1 classes.
# Using 2022 files for training.
# Found 2527 files belonging to 1 classes.
# Using 505 files for validation.

# %%
class_names = train.class_names

print("\nClasses:")
print(class_names)
# Out:
# Classes:
# ['Garbage classification']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train = train.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val = val.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# CNN Model
model = models.Sequential([

    layers.Rescaling(1./255, input_shape=(128,128,3)),

    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),

    layers.Dense(len(class_names), activation='softmax')
])
# Out:
# C:\Users\Maharshi Goswami\anaconda3\envs\project\lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,304,769 (12.61 MB)
#  Trainable params: 3,304,769 (12.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train,
    validation_data=val,
    epochs=10
)
# Out:
# Epoch 1/10
# C:\Users\Maharshi Goswami\anaconda3\envs\project\lib\site-packages\keras\src\ops\nn.py:944: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 164ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 2/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 4/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 6/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 8/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 10/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00

# %%
# Evaluate Model
loss, accuracy = model.evaluate(val)

print(f"\nValidation Accuracy: {accuracy*100:.2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Accuracy: 0.00%

# %%
# Accuracy Graph
plt.figure(figsize=(10,5))

plt.plot(history.history['accuracy'],
         label='Training Accuracy')

plt.plot(history.history['val_accuracy'],
         label='Validation Accuracy')

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("CNN Garbage Classification")

plt.legend()
plt.show()

# %%
# Save Model
model.save("garbage_classifier.h5")

print("Model Saved Successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved Successfully!
